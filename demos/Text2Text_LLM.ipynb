UserWarning: Initializing zero-element tensors is a no-op
#   warnings.warn("Initializing zero-element tensors is a no-op")
# Loading experts:   0%|          | 0/32 [00:00<?, ?it/s]

# %%
#OpenAI Chat Completion API

chat_history = [
    {"role": "user",  "content": "Hi"},
    {"role": "assistant", "content": "Hello, how are you?"},
    {"role": "user", "content": "What should I do today?"}
]
num_tokens = asst.chat_completion_tokens(chat_history) #29
print(num_tokens)

result = asst.chat_completion(chat_history, stream=True) #{'role': 'assistant', 'content': '1. Make a list of things to be grateful for.\n2. Go outside and take a walk in nature.\n3. Practice mindfulness meditation.\n4. Connect with a loved one or friend.\n5. Do something kind for someone else.\n6. Engage in a creative activity like drawing or writing.\n7. Read an uplifting book or listen to motivational podcasts.'}
print(result["content"])
# Out:
# 29
# That depends on your interests and what you have available to you. Here are a few suggestions:
#
# * Go
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-13a44c4fafd9> in <cell line: 11>()
#       9 print(num_tokens)
#      10
# ---> 11 result = asst.chat_completion(chat_history, stream=True) #{'role': 'assistant', 'content': '1. Make a list of things to be grateful for.\n2. Go outside and take a walk in nature.\n3. Practice mindfulness meditation.\n4. Connect with a loved one or friend.\n5. Do something kind for someone else.\n6. Engage in a creative activity like drawing or writing.\n7. Read an uplifting book or listen to motivational podcasts.'}
#      12 print(result["content"])
#
# /usr/local/lib/python3.10/dist-packages/text2text/assistant.py in chat_completion(self, messages, stream, **kwargs)
#      90       attention_mask = torch.ones_like(input_ids)
#      91
# ---> 92     results = model.generate(
#      93       input_ids=input_ids,
#      94       attention_mask=attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     113     def decorate_context(*args, **kwargs):
#     114         with ctx_factory():
# --> 115             return func(*args, **kwargs)
#     116
#     117     return decorate_context
#
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1523
#    1524             # 13. run sample
# -> 1525             return self.sample(
#    1526                 input_ids,
#    1527                 logits_processor=prepared_logits_processor,
#
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py in sample(self, input_ids, logits_processor, stopping_criteria, logits_warper, max_length, pad_token_id, eos_token_id, output_attentions, output_hidden_states, output_scores, return_dict_in_generate, synced_gpus, streamer, **model_kwargs)
#    2620
#    2621             # forward pass to get next token
# -> 2622             outputs = self(
#    2623                 **model_inputs,
#    2624                 return_dict=True,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/mixtral/modeling_mixtral.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, output_router_logits, return_dict)
#    1315
#    1316         # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# -> 1317         outputs = self.model(
#    1318             input_ids=input_ids,
#    1319             attention_mask=attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/mixtral/modeling_mixtral.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, output_router_logits, return_dict)
#    1183                 )
#    1184             else:
# -> 1185                 layer_outputs = decoder_layer(
#    1186                     hidden_states,
#    1187                     attention_mask=attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/mixtral/modeling_mixtral.py in forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, output_router_logits, use_cache, **kwargs)
#     902         residual = hidden_states
#     903         hidden_states = self.post_attention_layernorm(hidden_states)
# --> 904         hidden_states, router_logits = self.block_sparse_moe(hidden_states)
#     905         hidden_states = residual + hidden_states
#     906
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/text2text/mixtral/custom_layers.py in forward(self, hidden_states)
#     328             # states by `routing_weights` on the corresponding tokens (top-1 and top-2)
#     329             current_state = hidden_states[None, top_x_list].reshape(-1, hidden_dim)
# --> 330             current_hidden_states = expert_layer(current_state) * routing_weights[top_x_list, idx_list, None]
#     331
#     332             # However `index_add_` only support torch tensors for indexing so we'll use
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/text2text/mixtral/expert_wrapper.py in forward(self, *args, **kwargs)
#      53
#      54     def forward(self, *args, **kwargs):
# ---> 55         return self.expert_module(*args, **kwargs)
#      56
#      57
#
# /usr/local/lib/python3.10/dist-packages/text2text/mixtral/expert_wrapper.py in <lambda>(*args, **kwargs)
#      38
#      39         expert_module, self.storage = self.replace_layer_storage(expert_module, device)
# ---> 40         self.expert_module = lambda *args, **kwargs: expert_module(*args, **kwargs)
#      41
#      42         self._register_state_dict_hook(self._add_storage_to_state_dict_hook)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/text2text/mixtral/custom_layers.py in forward(self, hidden_states)
#     275     def forward(self, hidden_states):
#     276         current_hidden_states = self.act_fn(self.w1(hidden_states)) * self.w3(hidden_states)
# --> 277         current_hidden_states = self.w2(current_hidden_states)
#     278         return current_hidden_states
#     279
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1516             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517         else:
# -> 1518             return self._call_impl(*args, **kwargs)
#    1519
#    1520     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1525                 or _global_backward_pre_hooks or _global_backward_hooks
#    1526                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527             return forward_call(*args, **kwargs)
#    1528
#    1529         try:
#
# /usr/local/lib/python3.10/dist-packages/text2text/mixtral/custom_layers.py in forward(self, x)
#      70
#      71     def forward(self, x):
# ---> 72         return self.forward_triton(x)
#      73
#      74     def set_backend(self, backend):
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     113     def decorate_context(*args, **kwargs):
#     114         with ctx_factory():
# --> 115             return func(*args, **kwargs)
#     116
#     117     return decorate_context
#
# /usr/local/lib/python3.10/dist-packages/text2text/mixtral/custom_layers.py in forward_triton(self, x)
#     100             raise RuntimeError(f"nbits == {self.meta['nbits']} isn't yet supported")
#     101
# --> 102         output = fn(
#     103             meta['group_size'], x,
#     104             W_q.view(-1, K),
#
# /usr/local/lib/python3.10/dist-packages/text2text/mixtral/triton_kernels.py in triton_matmul2_transpose(groupsize, a, qweight, scales, zeros, bias)
#     381         triton.cdiv(M, META['BLOCK_SIZE_M']) * triton.cdiv(N, META['BLOCK_SIZE_N']),
#     382     )
# --> 383     matmul2_kernel_transpose[grid](
#     384         x, qweight, c,
#     385         scales, zeros,
#
# /usr/local/lib/python3.10/dist-packages/triton/runtime/autotuner.py in run(self, *args, **kwargs)
#     112             full_nargs = {**self.nargs, **kwargs, **self.best_config.kwargs}
#     113             config.pre_hook(full_nargs)
# --> 114         ret = self.fn.run(*args, num_warps=config.num_warps, num_stages=config.num_stages, **kwargs, **config.kwargs)
#     115         self.nargs = None
#     116         return ret
#
# <string> in matmul2_kernel_transpose(a_ptr, b_ptr, c_ptr, scales_ptr, zeros_ptr, M, N, K, stride_am, stride_ak, stride_bn, stride_bk, stride_cm, stride_cn, stride_scales_g, stride_scales_n, stride_zeros_g, stride_zeros_n, groupsize, NO_GROUPS, BLOCK_SIZE_M, BLOCK_SIZE_N, BLOCK_SIZE_K, GROUP_SIZE_M, grid, num_warps, num_stages, extern_libs, stream, warmup, device, device_type)
#
# KeyboardInterrupt:

# %%
# Running conversation
messages = []
while True:
  user_input = input("User: ")
  print()
  messages.append({"role": "user", "content": user_input})
  while asst.chat_completion_tokens(messages) > 32000-512:
    messages = messages[1:]
  print("Assistant: ")
  result = asst.chat_completion(messages, stream=True)
  messages.append(result)
  print()
# Out:
# User: what is pdt vs pst
#
# Assistant:
# PDT and PST are both terms
#
# User: terms of what
#
# Assistant:
# PDT and PST are both terms
#
# User: what is the difference
#
# Assistant:
# I apologize for the confusion. P
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-41a36cec5bc0> in <cell line: 3>()
#       2 messages = []
#       3 while True:
# ----> 4   user_input = input("User: ")
#       5   print()
#       6   messages.append({"role": "user", "content": user_input})
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
